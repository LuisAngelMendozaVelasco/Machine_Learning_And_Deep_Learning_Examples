# %% [markdown]
# # Standardize Sequence Lengths

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from keras import Sequential
from keras.layers import InputLayer, LSTM, Dropout, Dense, Softmax, Bidirectional
from keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

sns.set_style("whitegrid")

# %%
# To avoid:
# StdErr from Kernel Process OMP: Error #15: Initializing libiomp5md.dll, but found libiomp5 already initialized.
# OMP: Hint This means that multiple copies of the OpenMP runtime have been linked into the program.

import os

os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
dataset = tf.data.Dataset.list_files("../data/flooddata/*/*.csv", shuffle=False)

files = []
for file in dataset:
    files.append(file.numpy().decode())

labels = []
for file in files:
    labels.append(file.split("\\")[3])

files = np.array(files)
labels = pd.Categorical(labels).rename_categories(["0.0 ft", "0.19 ft", "2.5 ft", "4.5 ft"])

# %%
files_train, files_test, labels_train, labels_test = train_test_split(files, labels, test_size=0.2, stratify=labels)
files_test, files_validation, labels_test, labels_validation = train_test_split(files_test, labels_test, test_size=0.5, stratify=labels_test)

le = LabelEncoder()
le.fit(labels)

labels_train = le.transform(labels_train)
labels_train = tf.one_hot(labels_train, 4)

labels_test = le.transform(labels_test)
labels_test = tf.one_hot(labels_test, 4)

labels_validation = le.transform(labels_validation)
labels_validation = tf.one_hot(labels_validation, 4)

# %%
def load_array(file):
    df = pd.read_csv(file)
    array = df.to_numpy().T
    if array.shape[1]>=100:
        array = array[:, :100]
    return array

def create_dataset(files, labels):
    arrays = list(map(load_array, files))
    dataset = tf.data.Dataset.from_generator(lambda: iter(zip(arrays, labels)), output_types=(tf.float16, tf.uint8))
    return dataset

def configure_for_performance(dataset):
    dataset = dataset.cache()
    dataset = dataset.shuffle(buffer_size=222, reshuffle_each_iteration=True)
    dataset = dataset.padded_batch(32, padded_shapes=((3, 100), ([None])))
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    return dataset

train_dataset = create_dataset(files_train, labels_train.numpy())
train_dataset = configure_for_performance(train_dataset)

test_dataset = create_dataset(files_test, labels_test.numpy())
test_dataset = configure_for_performance(test_dataset)

validation_dataset = create_dataset(files_validation, labels_validation.numpy())
validation_dataset = configure_for_performance(validation_dataset)

# %%
model = Sequential([InputLayer(input_shape=(3, 100)),
                    Bidirectional(LSTM(128, return_sequences=False)), 
                    Dropout(0.5),
                    Dense(units=4), 
                    Softmax()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 256)              234496
#  l)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 4)                 1028
#
#  softmax (Softmax)           (None, 4)                 0
#
# =================================================================
# Total params: 235,524
# Trainable params: 235,524
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = Adam(learning_rate=0.0001)
loss = tf.keras.losses.CategoricalCrossentropy()
metrics = tf.keras.metrics.CategoricalAccuracy()
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
history = model.fit(train_dataset, epochs=25, validation_data=validation_dataset)
# Out:
# Epoch 1/25
# 6/6 [==============================] - 7s 518ms/step - loss: 1.3593 - categorical_accuracy: 0.3503 - val_loss: 1.3371 - val_categorical_accuracy: 0.3478
# Epoch 2/25
# 6/6 [==============================] - 0s 9ms/step - loss: 1.3784 - categorical_accuracy: 0.3051 - val_loss: 1.3312 - val_categorical_accuracy: 0.3478
# Epoch 3/25
# 6/6 [==============================] - 0s 9ms/step - loss: 1.3356 - categorical_accuracy: 0.3616 - val_loss: 1.3258 - val_categorical_accuracy: 0.3913
# Epoch 4/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.3462 - categorical_accuracy: 0.3220 - val_loss: 1.3205 - val_categorical_accuracy: 0.3913
# Epoch 5/25
# 6/6 [==============================] - 0s 9ms/step - loss: 1.3119 - categorical_accuracy: 0.4181 - val_loss: 1.3153 - val_categorical_accuracy: 0.4348
# Epoch 6/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2750 - categorical_accuracy: 0.4746 - val_loss: 1.3099 - val_categorical_accuracy: 0.4783
# Epoch 7/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2872 - categorical_accuracy: 0.4181 - val_loss: 1.3045 - val_categorical_accuracy: 0.4783
# Epoch 8/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2394 - categorical_accuracy: 0.4746 - val_loss: 1.2997 - val_categorical_accuracy: 0.5652
# Epoch 9/25
# 6/6 [==============================] - 0s 10ms/step - loss: 1.2351 - categorical_accuracy: 0.4802 - val_loss: 1.2946 - val_categorical_accuracy: 0.5652
# Epoch 10/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2169 - categorical_accuracy: 0.5763 - val_loss: 1.2898 - val_categorical_accuracy: 0.6087
# Epoch 11/25
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1990 - categorical_accuracy: 0.5763 - val_loss: 1.2849 - val_categorical_accuracy: 0.6522
# Epoch 12/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1911 - categorical_accuracy: 0.5876 - val_loss: 1.2797 - val_categorical_accuracy: 0.6957
# Epoch 13/25
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1662 - categorical_accuracy: 0.6384 - val_loss: 1.2743 - val_categorical_accuracy: 0.6957
# Epoch 14/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1604 - categorical_accuracy: 0.6271 - val_loss: 1.2690 - val_categorical_accuracy: 0.6957
# Epoch 15/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1403 - categorical_accuracy: 0.6667 - val_loss: 1.2639 - val_categorical_accuracy: 0.6957
# Epoch 16/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1472 - categorical_accuracy: 0.6328 - val_loss: 1.2590 - val_categorical_accuracy: 0.6957
# Epoch 17/25
# 6/6 [==============================] - 0s 9ms/step - loss: 1.1335 - categorical_accuracy: 0.6271 - val_loss: 1.2538 - val_categorical_accuracy: 0.6957
# Epoch 18/25
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0954 - categorical_accuracy: 0.7175 - val_loss: 1.2486 - val_categorical_accuracy: 0.6957
# Epoch 19/25
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0786 - categorical_accuracy: 0.7062 - val_loss: 1.2437 - val_categorical_accuracy: 0.6522
# Epoch 20/25
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0812 - categorical_accuracy: 0.7119 - val_loss: 1.2385 - val_categorical_accuracy: 0.6522
# Epoch 21/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0440 - categorical_accuracy: 0.7740 - val_loss: 1.2333 - val_categorical_accuracy: 0.6522
# Epoch 22/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0482 - categorical_accuracy: 0.7401 - val_loss: 1.2279 - val_categorical_accuracy: 0.6522
# Epoch 23/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0321 - categorical_accuracy: 0.8023 - val_loss: 1.2225 - val_categorical_accuracy: 0.6522
# Epoch 24/25
# 6/6 [==============================] - 0s 9ms/step - loss: 1.0289 - categorical_accuracy: 0.7458 - val_loss: 1.2173 - val_categorical_accuracy: 0.6522
# Epoch 25/25
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0175 - categorical_accuracy: 0.7966 - val_loss: 1.2123 - val_categorical_accuracy: 0.6522

# %%
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Categorical Accuracy')
plt.title('Training and Validation Accuracy')
plt.xticks(range(len(acc)), range(1, len(acc)+1))

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Categorical Crossentropy')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.xticks(range(len(loss)), range(1, len(loss)+1))

plt.show()

# %%
for signal, label in test_dataset:
   y_true = tf.argmax(label, axis=-1)
   predictions = model.predict(signal, verbose=False)
   y_pred = tf.argmax(predictions, axis=-1)

# %%
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["0.0 ft", "0.19 ft", "2.5 ft", "4.5 ft"])
disp.plot()
plt.grid(False)
plt.show()
