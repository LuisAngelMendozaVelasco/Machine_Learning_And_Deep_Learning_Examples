# %% [markdown]
# # Basketball Players

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.mixture import GaussianMixture
from sklearn.metrics import davies_bouldin_score

sns.set_style("whitegrid")

# %%
data = pd.read_csv("./data/bball.csv")
data.pos = pd.Categorical(data.pos)
data.head()
# Out:
#        bioID useFirst     lastName  pos  height  weight          college  \
# 0  abdelal01     Alaa    Abdelnaby  F-C    82.0     240             Duke
# 1  abdulma02  Mahmoud   Abdul-Rauf    G    73.0     162  Louisiana State
# 2  abdulta01    Tariq  Abdul-Wahad  G-F    78.0     223   San Jose State
# 3  abdursh01  Shareef  Abdur-Rahim    F    81.0     225       California
# 4  acresma01     Mark        Acres  F-C    83.0     220     Oral Roberts
#
#   hsState race   GP  ...  steals  blocks  turnovers      PF  fgAttempted  \
# 0      NJ    B  256  ...  0.2773  0.2734     0.9648  1.8906       4.8281
# 1      MS    B  586  ...  0.8311  0.0785     1.6433  1.8874      13.5546
# 2     NaN    B  236  ...  0.7797  0.3517     1.3093  2.0551       7.3136
# 3      GA    B  830  ...  0.9880  0.7687     2.5711  2.8000      13.8735
# 4      CA    W  154  ...  0.3442  0.2987     0.5714  2.5455       2.6883
#
#    fgMade  ftAttempted  ftMade  threeAttempted  threeMade
# ...

# %%
stats = data.iloc[:, [4, 5]+[i for i in range(10, data.shape[1])]]
stats.head()
# Out:
#    height  weight  minutes   points  oRebounds  dRebounds  assists  steals  \
# 0    82.0     240  12.5000   5.7227     1.1055     2.1992   0.3320  0.2773
# 1    73.0     162  26.6689  14.5956     0.3737     1.4812   3.5478  0.8311
# 2    78.0     223  20.3686   7.7542     1.2119     2.0763   1.1271  0.7797
# 3    81.0     225  34.7928  18.1060     2.2518     5.2651   2.5410  0.9880
# 4    83.0     220  16.2857   3.6169     1.7078     2.6948   0.3377  0.3442
#
#    blocks  turnovers      PF  fgAttempted  fgMade  ftAttempted  ftMade  \
# 0  0.2734     0.9648  1.8906       4.8281  2.4219       1.2539  0.8789
# 1  0.0785     1.6433  1.8874      13.5546  5.9966       1.9812  1.7935
# 2  0.3517     1.3093  2.0551       7.3136  3.0508       2.2415  1.5763
# 3  0.7687     2.5711  2.8000      13.8735  6.5470       5.9554  4.8265
# 4  0.2987     0.5714  2.5455       2.6883  1.3831       1.1948  0.8312
#
#    threeAttempted  threeMade
# 0          0.0117     0.0000
# ...

# %%
scaler = StandardScaler()
stats_normalized = scaler.fit_transform(stats)

# %%
model = GaussianMixture(n_components=2, reg_covar=0.02)
labels = model.fit_predict(stats_normalized)
# Out:
# c:\Users\luisa\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(

# %% [markdown]
# The DataFrame contains statistics for several basketball players. The players' positions are contained in data.pos.
# The numeric statistics have been extracted and normalized, then used in a Gaussian mixture model (GMM) to divide the players into two groups.

# %%
counts = pd.crosstab(data.pos, labels)
counts.columns.name = ''
counts.index.name = ''
counts
# Out:
#          0   1
#
# C       90  29
# C-F     34  10
# F      253  63
# F-C     80  38
# F-C-G    2   0
# F-G     36  13
# G      275  92
# G-F     79  20

# %%
plt.figure()
sns.heatmap(counts, annot=True, fmt="")
plt.show()

# %% [markdown]
# The Gaussian mixture model gmModel contains information about the underlying Gaussian distributions used to create the clusters. For example, we can extract the means of the distributions, which correspond to the centroids of the clusters.

# %%
aux = pd.DataFrame(model.means_)
aux['labels'] = [0, 1]
aux.sort_values(by='labels', inplace=True)

plt.figure()
pd.plotting.parallel_coordinates(aux, "labels", colormap='jet')
plt.xticks(ticks=range(stats.shape[1]), labels=stats.columns, rotation=60)
plt.show()

# %%
davies_bouldin_scores = {}
for n_cluster in range(2, 5):
    clusterer = GaussianMixture(n_components=2, reg_covar=0.02)
    cluster_labels = clusterer.fit_predict(stats_normalized)
    
    davies_bouldin_avg = davies_bouldin_score(stats_normalized, cluster_labels)
    davies_bouldin_scores[n_cluster] = davies_bouldin_avg
# Out:
# c:\Users\luisa\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\luisa\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# c:\Users\luisa\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(

# %%
print("Davies_bouldin evaluation:", davies_bouldin_scores)
print("Optimal number of clusters:", min(davies_bouldin_scores, key=davies_bouldin_scores.get))
# Out:
# Davies_bouldin evaluation: {2: 1.5039831198273437, 3: 1.5039831198273437, 4: 1.5039831198273437}
# Optimal number of clusters: 2
