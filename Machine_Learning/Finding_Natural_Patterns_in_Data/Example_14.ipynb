# %% [markdown]
# # Hierarchical Tree

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster import hierarchy

sns.set_style("whitegrid")

# %%
X = pd.read_csv("./data/X.csv", header=None)

# %% [markdown]
# We can use the [linkage()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.linkage.html) function to encode a tree of hierarchical clusters from a set of observations.

# %%
Z = hierarchy.linkage(X)

# %% [markdown]
# we can use the [dendrogram()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.dendrogram.html) function to visualize the hierarchy of a binary cluster tree.

# %%
hierarchy.dendrogram(Z, truncate_mode='lastp', p=30);

# %% [markdown]
# We can modify the way that linkage computes the distance between clusters by passing an optional second input. For example, the "ward" method computes the inner squared distance using Ward's minimum variance algorithm.

# %%
Z_ward = hierarchy.linkage(X, method='ward')

hierarchy.dendrogram(Z_ward, truncate_mode='lastp', p=30);
