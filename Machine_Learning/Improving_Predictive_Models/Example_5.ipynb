# %% [markdown]
# # Sequential Feature Selection

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold, cross_validate
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.metrics import make_scorer
import time

# %%
T = pd.read_csv("./data/pumpFeatures.csv")
X, y = T.iloc[:, :-1], T.faultCode
T.head()
# Out:
#    wMotor_mean  wMotor_std  wMotor_fftPeakIdx  wMotor_skewness  \
# 0   876.235677    6.204772                762        -0.164601
# 1   876.238247    6.077463                762        -0.147077
# 2   876.031159    6.250861                762        -0.123501
# 3   876.196665    6.247495                762        -0.134596
# 4   876.199734    6.095278                762        -0.139257
#
#    wMotor_kurtosis  wMotor_peak2peak  wMotor_peak2rms  wMotor_rms  wMotor_mad  \
# 0         2.881123         39.070726         1.018288  876.257629    5.032113
# 1         2.673731         34.570767         1.016957  876.259308    4.982643
# 2         2.551445         35.491460         1.017266  876.053444    5.165914
# 3         2.728913         41.529486         1.018873  876.218921    5.093603
# 4         2.705275         36.096733         1.018066  876.220919    4.962708
#
#    wMotor_csRange  ...  pOut_peak2peak  pOut_peak2rms  pOut_rms  pOut_mad  \
# 0    1.225859e+06  ...        0.125500       1.007635  7.226002  0.019002
# 1    1.225862e+06  ...        0.120924       1.007091  7.225622  0.018990
# 2    1.225575e+06  ...        0.131161       1.007494  7.225906  0.019032
# 3    1.225799e+06  ...        0.123254       1.007770  7.225914  0.018717
# 4    1.225812e+06  ...        0.123759       1.006735  7.225260  0.019078
#
#    pOut_csRange  pOut_pLow  pOut_pMid  pOut_pHigh  pOut_pKur  faultCode
# 0  10109.108199   0.000091   0.007472    0.001348   0.076296          0
# 1  10108.578309   0.000118   0.006954    0.001434   0.076296          0
# 2  10108.963684   0.000060   0.006570    0.001309   0.076296          0
# 3  10108.973834   0.000066   0.007190    0.001364   0.076296          0
# 4  10108.065292   0.000051   0.007814    0.001600   0.071808          0
#
# [5 rows x 85 columns]

# %% [markdown]
# This code fits a 5-fold cross-validated tree model to the original data and calculates the accuracy.

# %%
classifier = DecisionTreeClassifier()
kf = KFold(n_splits=5, shuffle=True)

start_time = time.time()
cv_results = cross_validate(classifier, X, y, cv=kf)
elapsed_time = time.time() - start_time

print("Accuracies:", cv_results['test_score'])
print("Mean accuracy:", cv_results['test_score'].mean())
print(f"Cross validation elapsed time: {elapsed_time:.4f} seconds")
# Out:
# Accuracies: [0.86  0.88  0.845 0.89  0.89 ]
# Mean accuracy: 0.873
# Cross validation elapsed time: 0.2084 seconds

# %% [markdown]
# Create a function that calculates the number of misclassifications given y_true and y_pred.

# %%
def score_func(y_true, y_pred):
    return (y_true != y_pred).sum()

scorer = make_scorer(score_func, greater_is_better=False)

# %% [markdown]
# Perform Sequential Feature Selection.

# %%
classifier = DecisionTreeClassifier()
kf = KFold(n_splits=5, shuffle=True)

sfs = SequentialFeatureSelector(classifier, n_features_to_select='auto', cv=kf, scoring=scorer)
sfs.fit(X, y)
# Out:
# SequentialFeatureSelector(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#                           estimator=DecisionTreeClassifier(),
#                           n_features_to_select='auto',
#                           scoring=make_scorer(score_func, greater_is_better=False))

# %%
X_selected = X.loc[:, sfs.get_support()]
X_selected.head()
# Out:
#    wMotor_mean  wMotor_std  wMotor_fftPeakIdx  wMotor_peak2peak  wMotor_rms  \
# 0   876.235677    6.204772                762         39.070726  876.257629
# 1   876.238247    6.077463                762         34.570767  876.259308
# 2   876.031159    6.250861                762         35.491460  876.053444
# 3   876.196665    6.247495                762         41.529486  876.218921
# 4   876.199734    6.095278                762         36.096733  876.220919
#
#    wMotor_csRange  iMotor_fftPeakIdx  iMotor_peak2rms  iMotor_rms  \
# 0    1.225859e+06                762         1.014779   38.233040
# 1    1.225862e+06                762         1.015027   38.226531
# 2    1.225575e+06                762         1.016187   38.231761
# 3    1.225799e+06                762         1.015062   38.231827
# 4    1.225812e+06                762         1.015704   38.229879
#
#    iMotor_csRange  ...  qOut_skewness  qOut_kurtosis   qOut_rms  qOut_mad  \
# 0    53487.133438  ...      -0.729159       2.766482  35.637498  2.237138
# 1    53478.048014  ...      -0.686943       2.688800  35.665423  2.250044
# 2    53485.122233  ...      -0.692149       2.722829  35.664385  2.219092
# 3    53485.537791  ...      -0.702165       2.731413  35.602140  2.258929
# 4    53482.758023  ...      -0.751425       2.855754  35.651921  2.220493
#
#    qOut_csRange  qOut_pLow  qOut_pHigh  qOut_pKur  pOut_mean  pOut_std
# 0  49707.083608   1.306950   17.302460   2.670354   7.225965  0.023251
# 1  49745.621125   0.637924   15.858150   2.733186   7.225584  0.023339
# 2  49746.636093   0.629772   16.690655   0.067320   7.225869  0.023258
# 3  49655.781850   0.561285   18.747575   0.363527   7.225877  0.023018
# 4  49726.524042   0.696649   19.024521   2.917193   7.225222  0.023405
#
# [5 rows x 42 columns]

# %% [markdown]
# Fit and evaluate a 5-fold cross-validated tree model with the selected variables.

# %%
classifier = DecisionTreeClassifier()
kf = KFold(n_splits=5, shuffle=True)

start_time = time.time()
cv_results = cross_validate(classifier, X_selected, y, cv=kf)
elapsed_time = time.time() - start_time

print("Accuracies:", cv_results['test_score'])
print("Mean accuracy:", cv_results['test_score'].mean())
print(f"Cross validation elapsed time: {elapsed_time:.4f} seconds")
# Out:
# Accuracies: [0.86  0.87  0.845 0.91  0.87 ]
# Mean accuracy: 0.8710000000000001
# Cross validation elapsed time: 0.1164 seconds
